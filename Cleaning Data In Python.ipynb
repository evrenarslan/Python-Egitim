# %%
import requests
import pandas as pd

# %%
url = 'https://data.ibb.gov.tr/api/3/action/datastore_search?resource_id=50036dfd-aea5-4f06-832f-f7020fdaaa5a'  
ibb_data_test=requests.get(url)
ibb_data=r.json()

# %%
for key,value in ibb_data.items():
    print(key+":",value)
# Out:
# help: https://data.ibb.gov.tr/api/3/action/help_show?name=datastore_search
# success: True
# ...
